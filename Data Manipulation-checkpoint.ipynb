# %%
import pandas as pd

# %%
filepath = "DataFiles/Data.xlsx"
df = pd.read_excel(filepath)

# %%
df.head(7)
# Out:
#       name  age   department  salary
# 0    Alice   30           HR   50000
# 1      Bob   24  Engineering   60000
# 2  Charlie   26        Sales   55000
# 3    David   35  Engineering   80000
# 4      Eve   29           HR   52000
# 5    Frank   27        Sales   58000
# 6    Grace   31  Engineering   70000

# %%
df.tail(10)
# Out:
#        name  age   department  salary
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 3     David   35  Engineering   80000
# 4       Eve   29           HR   52000
# 5     Frank   27        Sales   58000
# 6     Grace   31  Engineering   70000
# 7    Hannah   23        Sales   53000
# 8       Ian   34           HR   51000
# 9      Jack   28  Engineering   62000
# 10      Eve   29           HR   52000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        11 non-null     object
#  1   age         11 non-null     int64
#  2   department  11 non-null     object
#  3   salary      11 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 484.0+ bytes

# %%
df.shape
# Out:
# (11, 4)

# %%
df.columns
# Out:
# Index(['name', 'age', 'department', 'salary'], dtype='object')

# %%
df.describe()
# Out:
#              age        salary
# count  11.000000     11.000000
# mean   28.727273  58454.545455
# std     3.744086   9299.071312
# min    23.000000  50000.000000
# 25%    26.500000  52000.000000
# 50%    29.000000  55000.000000
# 75%    30.500000  61000.000000
# max    35.000000  80000.000000

# %%
selected = df[["age", "salary"]]

# %%
selected
# Out:
#     age  salary
# 0    30   50000
# 1    24   60000
# 2    26   55000
# 3    35   80000
# 4    29   52000
# 5    27   58000
# 6    31   70000
# 7    23   53000
# 8    34   51000
# 9    28   62000
# 10   29   52000

# %%
df.iloc[3:8]
# Out:
#      name  age   department  salary
# 3   David   35  Engineering   80000
# 4     Eve   29           HR   52000
# 5   Frank   27        Sales   58000
# 6   Grace   31  Engineering   70000
# 7  Hannah   23        Sales   53000

# %%
df.head()
# Out:
#       name  age   department  salary
# 0    Alice   30           HR   50000
# 1      Bob   24  Engineering   60000
# 2  Charlie   26        Sales   55000
# 3    David   35  Engineering   80000
# 4      Eve   29           HR   52000

# %%
df.sort_values(by = "salary",)
# Out:
#        name  age   department  salary
# 0     Alice   30           HR   50000
# 8       Ian   34           HR   51000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 7    Hannah   23        Sales   53000
# 2   Charlie   26        Sales   55000
# 5     Frank   27        Sales   58000
# 1       Bob   24  Engineering   60000
# 9      Jack   28  Engineering   62000
# 6     Grace   31  Engineering   70000
# 3     David   35  Engineering   80000

# %%
df.sort_values(by = "salary",ascending=False)
# Out:
#        name  age   department  salary
# 3     David   35  Engineering   80000
# 6     Grace   31  Engineering   70000
# 9      Jack   28  Engineering   62000
# 1       Bob   24  Engineering   60000
# 5     Frank   27        Sales   58000
# 2   Charlie   26        Sales   55000
# 7    Hannah   23        Sales   53000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 8       Ian   34           HR   51000
# 0     Alice   30           HR   50000

# %%
df.sort_values(by = "age")
# Out:
#        name  age   department  salary
# 7    Hannah   23        Sales   53000
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 5     Frank   27        Sales   58000
# 9      Jack   28  Engineering   62000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 0     Alice   30           HR   50000
# 6     Grace   31  Engineering   70000
# 8       Ian   34           HR   51000
# 3     David   35  Engineering   80000

# %%
df.sort_values(by = "age",ascending=False)
# Out:
#        name  age   department  salary
# 3     David   35  Engineering   80000
# 8       Ian   34           HR   51000
# 6     Grace   31  Engineering   70000
# 0     Alice   30           HR   50000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 9      Jack   28  Engineering   62000
# 5     Frank   27        Sales   58000
# 2   Charlie   26        Sales   55000
# 1       Bob   24  Engineering   60000
# 7    Hannah   23        Sales   53000

# %%
df[df["age"] < 25]
# Out:
#      name  age   department  salary
# 1     Bob   24  Engineering   60000
# 7  Hannah   23        Sales   53000

# %%
df["age"] < 25
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# Name: age, dtype: bool

# %%
df["salary"] < 55000
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10     True
# Name: salary, dtype: bool

# %%
df["Lcation"]="Kisumu"

# %%
df
# Out:
#        name  age   department  salary Lcation
# 0     Alice   30           HR   50000  Kisumu
# 1       Bob   24  Engineering   60000  Kisumu
# 2   Charlie   26        Sales   55000  Kisumu
# 3     David   35  Engineering   80000  Kisumu
# 4       Eve   29           HR   52000  Kisumu
# 5     Frank   27        Sales   58000  Kisumu
# 6     Grace   31  Engineering   70000  Kisumu
# 7    Hannah   23        Sales   53000  Kisumu
# 8       Ian   34           HR   51000  Kisumu
# 9      Jack   28  Engineering   62000  Kisumu
# 10      Eve   29           HR   52000  Kisumu

# %%
df["Location"]= "Nairobi"

# %%
df.iloc[7],"Location"
# Out:
# (name              Hannah
#  age                   23
#  department         Sales
#  salary             53000
#  Lcation           Kisumu
#  Location          Kisumu
#  (Location, 7)    Nairobi
#  Name: 7, dtype: object,
#  'Location')

# %%
df.loc[df["name"] == "Hannah", "Location"] = "Nyeri"

# %%
df.drop(columns="Lcation")
# Out:
#        name  age   department  salary Location (Location, 7)
# 0     Alice   30           HR   50000  Nairobi       Nairobi
# 1       Bob   24  Engineering   60000  Nairobi       Nairobi
# 2   Charlie   26        Sales   55000  Nairobi       Nairobi
# 3     David   35  Engineering   80000  Nairobi       Nairobi
# 4       Eve   29           HR   52000  Nairobi       Nairobi
# 5     Frank   27        Sales   58000  Nairobi       Nairobi
# 6     Grace   31  Engineering   70000  Nairobi       Nairobi
# 7    Hannah   23        Sales   53000    Nyeri       Nairobi
# 8       Ian   34           HR   51000  Nairobi       Nairobi
# 9      Jack   28  Engineering   62000  Nairobi       Nairobi
# 10      Eve   29           HR   52000  Nairobi       Nairobi

# %%
df.drop(columns="Location", axis=1)
# Out:
#        name  age   department  salary Lcation (Location, 7)
# 0     Alice   30           HR   50000  Kisumu       Nairobi
# 1       Bob   24  Engineering   60000  Kisumu       Nairobi
# 2   Charlie   26        Sales   55000  Kisumu       Nairobi
# 3     David   35  Engineering   80000  Kisumu       Nairobi
# 4       Eve   29           HR   52000  Kisumu       Nairobi
# 5     Frank   27        Sales   58000  Kisumu       Nairobi
# 6     Grace   31  Engineering   70000  Kisumu       Nairobi
# 7    Hannah   23        Sales   53000  Kisumu       Nairobi
# 8       Ian   34           HR   51000  Kisumu       Nairobi
# 9      Jack   28  Engineering   62000  Kisumu       Nairobi
# 10      Eve   29           HR   52000  Kisumu       Nairobi
